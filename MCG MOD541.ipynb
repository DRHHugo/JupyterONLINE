# %% [markdown]
# # Este programa define un MCG con moóulo 541. El multiplicador y la semilla son ingresados como argumentos

# %%
def MCGmod541(b,x0,n):
    sample=[b*x0%541]
    for i in range(n-1):
        sample.append(b*sample[-1]%541)
    return sample

# %%
sample1=MCGmod541(2,10,540)

# %%
sample1.count(20)
# Out:
# 1

# %%
sample2=MCGmod541(86,346,540)

# %%
sample2.count(sample2[0])
# Out:
# 1

# %%
sample3=MCGmod541(85,1,540)
sample3.count(1)
# Out:
# 5

# %%
sample3
# Out:
# [85,
#  192,
#  90,
#  76,
#  509,
#  526,
#  348,
#  366,
#  273,
#  483,
#  480,
#  225,
#  190,
#  461,
#  233,
#  329,
#  374,
#  412,
#  396,
#  118,
#  292,
#  475,
#  341,
#  312,
#  11,
#  394,
#  489,
#  449,
#  295,
#  189,
#  376,
#  41,
#  239,
#  298,
#  444,
#  411,
#  311,
#  467,
#  202,
#  399,
#  373,
#  327,
#  204,
#  28,
#  216,
#  507,
#  356,
#  505,
#  186,
#  121,
#  6,
#  510,
#  70,
#  540,
#  456,
#  349,
#  451,
#  465,
#  32,
#  15,
#  193,
#  175,
#  268,
#  58,
#  61,
#  316,
#  351,
#  80,
#  308,
#  212,
#  167,
#  129,
#  145,
#  423,
#  249,
#  66,
#  200,
#  229,
#  530,
#  147,
#  52,
#  92,
#  246,
#  352,
#  165,
#  500,
#  302,
#  243,
#  97,
#  130,
#  230,
#  74,
#  339,
#  142,
#  168,
#  214,
#  337,
#  513,
#  325,
#  34,
#  185,
#  36,
#  355,
#  420,
#  535,
#  31,
#  471,
#  1,
#  85,
#  192,
#  90,
#  76,
#  509,
#  526,
#  348,
#  366,
#  273,
#  483,
#  480,
#  225,
#  190,
#  461,
#  233,
#  329,
#  374,
#  412,
#  396,
#  118,
# ...
